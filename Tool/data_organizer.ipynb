# %%
# Import libraries

import pandas as pd
import numpy as np
from dash import Dash, html, dcc, Input, Output, callback, dash_table, State
from datetime import datetime as dt
from datetime import timedelta
import dash_bootstrap_components as dbc
import plotly.graph_objects as go
import random
import plotly.express as px
from plotly.subplots import make_subplots
from dash import html
import os
import dash
import datetime
import subprocess
import webbrowser

# %%
test_data_old = pd.read_excel('all_txt_folder_data.xlsx', header = 0, sheet_name = 'datas_323_comma') # Import data from new database

# %%
test_data_old.head(5)
# Out:
#                                          Note       Time Stamp  RP1  RP6  RP7  \
# 0        R134a 1,6 kg collaudo per ripristino  0 days 00:08:47  0.0  0.0  0.0
# 1     R410A precarica 2.0 kg  VT tutta aperta  0 days 00:04:10  0.0  0.0  0.0
# 2  aggiunto 500 gr tot 2,5 kg VT tutta aperta  0 days 00:07:31  0.0  0.0  0.0
# 3  aggiunto 500 gr tot 3,0 kg VT tutta aperta  0 days 00:05:56  0.0  0.0  0.0
# 4  aggiunto 500 gr tot 3,5 kg VT tutta aperta  0 days 00:04:30  0.0  0.0  0.0
#
#    RV3V21  RV3V24  RV3V26  RFANS  RVP_A  ...  GAS REFRIGERANTE  REVISIONE  \
# 0    0.00   49.53   59.88    0.0    0.0  ...      R134a_PA.txt        NaN
# 1   29.61   51.84   23.17   70.0    0.0  ...      R410a_PA.txt        0.0
# 2   43.91   60.78   45.07   60.0    0.0  ...      R410a_PA.txt        0.0
# 3   37.05   67.15   12.44   60.0    0.0  ...      R410a_PA.txt        0.0
# 4   37.05   66.44   26.83   60.0    0.0  ...      R410a_PA.txt        0.0
#
# ...
